# %% [markdown]
# # Project 1: Multiclass Classification on EUROSAT

# %% [markdown]
# Welcome to your first project *Multiclass Classification on EUROSAT*! This notebook will guide you through elementary steps that need to be taken in many machine learning projects.

# %% [markdown]
# Submissions for Project 1 are due on **November 20th** via your group's folder in Stud.IP (please find more details towards the end of this notebook).

# %% [markdown]
# 1. Execute the following code to import required packages.

# %%
# %load_ext nb_black

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras

# %% [markdown]
# ## 1.1 Before Training

# %% [markdown]
# ### Loading the data
#
# 2. Load the dataset ```EUROSAT``` in the version ```2.0.0```. To that end, call the function ```tfds.load``` only once and such that it returns a list ```[train_ds, val_ds, test_ds]``` as well as an object ```info``` of type ```tfds.core.DatasetInfo```. As a result, ```train_ds``` shall contain the first ```80%``` of the training split, ```val_ds``` shall contain the next ```10%``` of the training split, and ```test_ds``` shall contain the last ```10%``` of the training split of ```EUROSAT```.
#
# Useful information can be found under https://www.tensorflow.org/datasets/catalog/eurosat and https://www.tensorflow.org/datasets/overview.

# %%
# your code
# tfds.list_builders()

# %%
(train_ds, val_ds, test_ds), info = tfds.load(
    "eurosat",
    split=["train[:80%]", "train[80%:90%]", "train[90%:]"],
    #     as_supervised=True,
    with_info=True,
)

# %%
info
# Out:
# tfds.core.DatasetInfo(
#     name='eurosat',
#     full_name='eurosat/rgb/2.0.0',
#     description="""
#     EuroSAT dataset is based on Sentinel-2 satellite images covering 13 spectral
#     bands and consisting of 10 classes with 27000 labeled and
#     geo-referenced samples.
#
#     Two datasets are offered:
#     - rgb: Contains only the optical R, G, B frequency bands encoded as JPEG image.
#     - all: Contains all 13 bands in the original value range (float32).
#
#     URL: https://github.com/phelber/eurosat
#     """,
#     config_description="""
#     Sentinel-2 RGB channels
#     """,
#     homepage='https://github.com/phelber/eurosat',
#     data_path='C:\\Users\\psraj\\tensorflow_datasets\\eurosat\\rgb\\2.0.0',
#     file_format=tfrecord,
#     download_size=89.91 MiB,
#     dataset_size=89.50 MiB,
#     features=FeaturesDict({
#         'filename': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(64, 64, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=27000, num_shards=1>,
#     },
#     citation="""@misc{helber2017eurosat,
#         title={EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification},
#         author={Patrick Helber and Benjamin Bischke and Andreas Dengel and Damian Borth},
#         year={2017},
#         eprint={1709.00029},
#         archivePrefix={arXiv},
#         primaryClass={cs.CV}
#     }""",
# )

# %%
train_ds
# Out:
# <PrefetchDataset element_spec={'filename': TensorSpec(shape=(), dtype=tf.string, name=None), 'image': TensorSpec(shape=(64, 64, 3), dtype=tf.uint8, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None)}>

# %% [markdown]
# The loaded datasets ```train_ds```, ```val_ds``` and ```test_ds``` are objects of type ```tensorflow.data.Dataset``` (or of a derived class). Moreover, ```info``` is an object of type ```tfds.core.DatasetInfo``` that contains useful information about the loaded data. In the following, you will first take a closer look at ```info```. Afterwards, you will learn how to access dataset items.

# %% [markdown]
# ### Looking at the big picture
#
# Use ```info``` to get a rough overview about ```EUROSAT```. Each ```item``` contained in ```train_ds```, ```val_ds``` and ```test_ds``` is a ```dictionary``` with keys ```"image"``` and ```"label"```.
#
# 3. Print the following information in the specified order:
#    - Image shape (shape of ```item["image"]```)
#    - Label shape (shape of ```item["label"]```)
#    - Number of classes
#    - Class names
#    - Number of training examples
#
# All these information can be extracted from ```info```. Do **not** use ```train_ds```, ```val_ds``` or ```test_ds``` directly. Print the first information using ```print("Image shape: {}".format(YOUR_CODE))``` and proceed analogously in the other cases.

# %%
# your code
# dataset_info.features["Image"].shape
print(f'Image Shape: {info.features["image"].shape}')
print(f'Label Shape: {info.features["label"].shape}')
print(f'Number of classes: {info.features["label"].num_classes}')
print(f'Class Name: {info.features["label"].names}')
print(f'Number of training examples: {info.splits["train"].num_examples}')
# Out:
# Image Shape: (64, 64, 3)
# Label Shape: ()
# Number of classes: 10
# Class Name: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
# Number of training examples: 27000

# %% [markdown]
# **Checkpoint**: Your code should produce the following output.
#
# ```
# Image shape: (64, 64, 3)
# Label shape: ()
# Number of classes: 10
# Class names: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']
# Number of training examples: 27000
# ```

# %% [markdown]
# Next, we will display a subset of the loaded images.
#
# 4. Use the function ```tfds.show_examples``` with optional arguments ```rows=2``` and ```cols=5```, to display ten items from ```train_ds```.

# %%
# your code
# tfds.show_examples(train_ds, dataset_info)
tfds.show_examples(train_ds, info, rows=2, cols=5)

# %% [markdown]
# We do already know the number of elements in the full ```EUROSAT``` dataset. However, we subdivided the original training split into training, validation and test data. Moreover, we do not know how many items from which class are in the respective subsets.
#
# 5. Write a function ```count_occurences``` that takes as input a dataset ```ds``` and an object ```info```, and returns an array ```num_occurences```. Therein, ```num_occurences[i]``` represents the number of elements with ```item["label"] = i``` in ```ds```.
#
# You can iterate over all elements in ```ds``` using a loop in the form of ```for item in ds: ...```.

# %%
# your code
# def count_occurences(dataset, dataset_info):

#     for item in ds:
#         item["label"] = i
#         return num_occurences[i]


# def count_occurences(ds, info):
#     labels, num_occurences = np.unique(
#         np.fromiter(ds.map(lambda x, y: y), np.int64), return_counts=True
#     )
#     return num_occurences


def count_occurences(dataset, info):
    counter = dict.fromkeys(range(10), 0)
    for item in dataset:
        counter[int(item["label"])] = counter[int(item["label"])] + 1
    num_occurance = np.array(list(counter.values()))
    return num_occurance

# %% [markdown]
# 6. Apply your function to ```train_ds```, ```val_ds``` und ```test_ds``` and print the frequencies of occurence of all classes in the respective datasets. Use
# ```python
# train_occurences = YOUR_CODE
# print("train_ds:\t {}".format(train_occurences))
# ```
# for the first output, and format the other two accordingly.

# %%
# your code

train_occurences = count_occurences(train_ds, info)
print(f"train_ds:\t {train_occurences}")
val_occurences = count_occurences(val_ds, info)
print(f"val_ds:\t \t {val_occurences}")
test_occurences = count_occurences(test_ds, info)
print(f"test_ds:\t {test_occurences}")
# Out:
# train_ds:	 [2427 2425 2379 1996 1999 1603 1996 2392 1989 2394]
# val_ds:	 	 [297 289 304 252 244 206 237 298 266 307]
# test_ds:	 [276 286 317 252 257 191 267 310 245 299]

# %% [markdown]
# **Checkpoint:** Your code should produce the following output.
#
# ```
# train_ds:	 [2427 2425 2379 1996 1999 1603 1996 2392 1989 2394]
# val_ds:		 [297 289 304 252 244 206 237 298 266 307]
# test_ds:	 [276 286 317 252 257 191 267 310 245 299]
# ```
#
# The number of elements in a dataset can alternatively be accessed via the method ```tensorflow.data.Dataset.cardinality```.

# %% [markdown]
# Finally, let us get an idea of the range of values of the loaded images.
#
# 7. Print the data format ```item["image"].dtype``` as well as the smallest and largest entry of an arbitrary element ```item``` from ```train_ds```. Format the output analogous to above.
#
# By calling ```train_ds.take(1)``` you obtain a new dataset of type ```tensorflow.data.Dataset``` that contains only one item from ```train_ds```. The functions ```np.min``` and ```np.max``` can be helpful in order to compute the smallest and largest entries of an image. Although ```item["image"]``` is a tensor, you can apply ```numpy``` functions directly to it. In case you ever want to cast ```item["image"]``` (or any other tensor) explicitly as a ```numpy``` array (which does not apply here), the method ```item["image"].numpy()``` is for you.

# %%
# your code
new_ds = train_ds.take(1)
# for i in new_ds_numpy:
#     print(i)

# new_ds_numpy = tfds.as_numpy(new_ds)
# # data = tfds.as_numpy(new_ds)
# for item in new_ds_numpy:
#     print(f"Smallest entries of the image: {np.min(item[0])}")
#     print(f"Largest entries of the image: {np.max(item[0])}")

for entry in new_ds:
    data = entry["image"].numpy()
    print(entry["image"].dtype)
    print(f"Smallest entry of the image: {np.min(data)}")
    print(f"Largest entry of the image: {np.max(data)}")
# Out:
# <dtype: 'uint8'>
# Smallest entry of the image: 26
# Largest entry of the image: 98

# %% [markdown]
# ### Preprocessing the data
# In the previous step we have seen that the data are in integer format with entries in the range $\{0,\dots,255\}$ (well, we actually only looked at a single image, but a look at the entire dataset would reveal that this is true). In terms of a training algorithm to be used later, it is often advantageous to rescale the data to a smaller interval. Now, we will rescale all images from ```train_ds```, ```val_ds``` und ```test_ds``` to the range $[0, 1]$ through division by $255$. At the same time, we will transform all elements ```item``` from a ```dictionary``` to a tuple ```(item["image"] / 255, item["label"])```.
#
# 8. Write a function ```preprocess``` that takes as input an element ```item``` and returns a tuple as described above.

# %%
# your code
def preprocess(item):
    return (item["image"] / 255, item["label"])

# %% [markdown]
# 9. Transform the datasets ```train_ds```, ```val_ds``` und ```test_ds``` using your function ```preprocess```. One call ```ds = ds.map(preprocess)``` is enough to transform a full dataset.

# %%
# your code
train_ds = train_ds.map(preprocess)
val_ds = val_ds.map(preprocess)
test_ds = test_ds.map(preprocess)

# %%
# train_ds

# %% [markdown]
# The class ```tf.data.Dataset``` provides various methods that can simplify the transformation of single items or entire datasets drastically. Two such methods are the above-mentioned ```tf.data.Dataset.take```, which requires an argument ```count``` and returns a new dataset including the first ```count``` elements of the calling dataset, as well as ```tf.data.Dataset.map```, which requires a function ```preprocess``` as input and applies this function automatically to all items in the dataset.
#
# Further methods from ```tf.data.Dataset```, which we will now use to construct an **input pipeline**, are
# - ```tf.data.Dataset.repeat``` to repeat a dataset a certain number of times,
# - ```tf.data.Dataset.shuffle``` to shuffle the items of a dataset randomly,
# - ```tf.data.Dataset.batch``` to group items of a dataset in batches of a certain size,
# - ```tf.data.Dataset.prefetch```.
#
# The usage of ```tf.data.Dataset``` is particularly efficient because only a fraction of the entire dataset is kept in the working memory at each time during training. Required data are loaded sequentially from disk into working memory and preprocessed. The method ```prefetch``` takes care that a specific number of batches will always be buffered ahead of time in the working memory. This prevents delays during training that could be caused by data loading and preprocessing. Further information can be found under https://www.tensorflow.org/api_docs/python/tf/data/Dataset.
#
# 10. Define ```batch_size = 32``` (will be needed in the next step). Then, apply the methods ```repeat``` (without argument), ```shuffle``` (with arguments ```buffer_size=1024``` and ```seed=0```), ```batch``` (with argument ```batch_size=batch_size```) and ```prefetch``` (with argument ```buffer_size=1```) to ```train_ds``` (in the specified order).

# %%
# your code
batch_size = 32
train_ds = train_ds.repeat()
train_ds = train_ds.shuffle(buffer_size=1024, seed=0)
train_ds = train_ds.batch(batch_size=batch_size)
train_ds = train_ds.prefetch(buffer_size=1)

# %% [markdown]
# 11. Execute the follwing code:

# %%
for item in train_ds.take(1):
    print(item[0].shape)
    plt.imshow(item[0][0, ...], cmap="gray")
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(f"Label: {item[1][0]}")
    plt.show()
# Out:
# (32, 64, 64, 3)

# %% [markdown]
# **Checkpoint:** You should get as output ```(32, 64, 64, 3)``` as well as (on first execution) an image showing forest.

# %% [markdown]
# 12. Transform ```val_ds``` and ```test_ds``` in the same way, only omit calls of ```repeat``` and ```shuffle``` (would be without effect here) and use ```batch_size=1``` in the case of ```test_ds```.
#
# You can either put all these calls into one line of code per dataset, or use a new line for each transformation. Be aware that each above-mentioned method returns a new dataset, as opposed to modifying a dataset in place.

# %%
# your code
##Val_Ds
val_ds = val_ds.batch(batch_size=batch_size)
val_ds = val_ds.prefetch(buffer_size=1)
##Test_DS
test_ds = test_ds.batch(batch_size=1)
test_ds = test_ds.prefetch(buffer_size=1)

# %% [markdown]
# ## 1.2 Training phase
#
# Now that inspection and preprocessing of the data are finished, we will use ```tensorflow.keras``` to define a first neural network model and train that model on the ```EUROSAT``` data.

# %% [markdown]
# ### Model definition
#
# 13. Use the Keras Sequential API to define a *fully connected* model ```model``` featuring the following architecture:
#
#  - One (parameter-free) input layer to vectorize the input data,
#  - one hidden layer with 256 neurons and ReLU activation function,
#  - one output layer with a suitable number of neurons and softmax activation function.
#
#
# Helpful information can be found under https://www.tensorflow.org/api_docs/python/tf/keras/Sequential/. Regarding the input layer, use ```keras.layers.Flatten()``` and submit the argument ```input_shape``` to inform the model about the input data format. To that end, you can use ```info.features["image"].shape``` again.

# %%
# your code


model = tf.keras.Sequential()
model.add(tf.keras.layers.InputLayer(input_shape=info.features["image"].shape))
model.add(tf.keras.layers.Flatten())
model.add(
    tf.keras.layers.Dense(
        256,
        #         input_shape=info.features["image"].shape,
        activation=tf.keras.layers.ReLU(),
    )
)
model.add(
    tf.keras.layers.Dense(
        info.features["label"].num_classes, activation=tf.keras.activations.softmax
    )
)

# %% [markdown]
# ### Model summary
#
# 14. Use ```model.summary``` to display a summary of your model.

# %%
# your code
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 12288)             0
#
#  dense (Dense)               (None, 256)               3145984
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 3,148,554
# Trainable params: 3,148,554
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Checkpoint:** The end of the output of ```model.summary()``` should be as follows.
#
# ```
# Total params: 3,148,554
# Trainable params: 3,148,554
# Non-trainable params: 0
# ```

# %% [markdown]
# ### Training
#
# 15. Call ```model.compile``` to compile your model. Use the loss function ```keras.losses.sparse_categorical_crossentropy```, the optimizer ```keras.optimizers.Adam```, as well as the metric ```keras.metrics.sparse_categorical_accuracy```. Moreover, use a learning rate rate schedule to implement a learning rate decay from initially ```1e-4``` to eventually ```1e-8```. Be sure to set the argument ```decay_steps``` of the schedule appropriately. Useful information can be found under https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/PolynomialDecay.

# %%
epochs = 100  # hint: you need this here

# your code
starter_learning_rate = 1e-4
end_learning_rate = 1e-8
decay_steps = 100000
learning_rate_fn = tf.keras.optimizers.schedules.PolynomialDecay(
    starter_learning_rate, decay_steps, end_learning_rate, power=0.9
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate_fn),
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)

# %% [markdown]
# 16. Call ```model.fit``` with return value ```history``` to train your model for 100 epochs (as indicated in the previous cell) on ```train_ds```. Use the argument ```steps_per_epoch``` to pass the number of batches that need to be processed in each epoch. This number corresponds to the sum of entries of ```train_occurences``` divided by ```batch_size``` (round up). Also pass validation data ```val_ds```.

# %%
# your code

# your code here 
history = model.fit(
    train_ds,
    epochs=epochs,
    steps_per_epoch=np.ceil(sum(train_occurences) / batch_size),
    validation_data = val_ds
)
# Out:
# Epoch 1/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.8502 - sparse_categorical_accuracy: 0.3054 - val_loss: 1.7253 - val_sparse_categorical_accuracy: 0.3111
# Epoch 2/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.6780 - sparse_categorical_accuracy: 0.3724 - val_loss: 1.6627 - val_sparse_categorical_accuracy: 0.4004
# Epoch 3/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.6129 - sparse_categorical_accuracy: 0.4043 - val_loss: 1.5909 - val_sparse_categorical_accuracy: 0.4067
# Epoch 4/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.5715 - sparse_categorical_accuracy: 0.4236 - val_loss: 1.5430 - val_sparse_categorical_accuracy: 0.4174
# Epoch 5/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.5252 - sparse_categorical_accuracy: 0.4437 - val_loss: 1.5348 - val_sparse_categorical_accuracy: 0.4567
# Epoch 6/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.5108 - sparse_categorical_accuracy: 0.4449 - val_loss: 1.4993 - val_sparse_categorical_accuracy: 0.4700
# Epoch 7/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.4841 - sparse_categorical_accuracy: 0.4569 - val_loss: 1.5125 - val_sparse_categorical_accuracy: 0.4570
# Epoch 8/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.4635 - sparse_categorical_accuracy: 0.4706 - val_loss: 1.5300 - val_sparse_categorical_accuracy: 0.4481
# Epoch 9/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.4428 - sparse_categorical_accuracy: 0.4791 - val_loss: 1.4864 - val_sparse_categorical_accuracy: 0.4785
# Epoch 10/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.4237 - sparse_categorical_accuracy: 0.4881 - val_loss: 1.4450 - val_sparse_categorical_accuracy: 0.4752
# Epoch 11/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.4050 - sparse_categorical_accuracy: 0.4932 - val_loss: 1.4553 - val_sparse_categorical_accuracy: 0.4726
# Epoch 12/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3838 - sparse_categorical_accuracy: 0.5042 - val_loss: 1.4354 - val_sparse_categorical_accuracy: 0.4863
# Epoch 13/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3740 - sparse_categorical_accuracy: 0.5075 - val_loss: 1.4240 - val_sparse_categorical_accuracy: 0.4867
# Epoch 14/100
# 675/675 [==============================] - 3s 5ms/step - loss: 1.3574 - sparse_categorical_accuracy: 0.5151 - val_loss: 1.4008 - val_sparse_categorical_accuracy: 0.4981
# Epoch 15/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3502 - sparse_categorical_accuracy: 0.5213 - val_loss: 1.3745 - val_sparse_categorical_accuracy: 0.4996
# Epoch 16/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3338 - sparse_categorical_accuracy: 0.5263 - val_loss: 1.4188 - val_sparse_categorical_accuracy: 0.4848
# Epoch 17/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3126 - sparse_categorical_accuracy: 0.5319 - val_loss: 1.3851 - val_sparse_categorical_accuracy: 0.4978
# Epoch 18/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.3069 - sparse_categorical_accuracy: 0.5340 - val_loss: 1.3483 - val_sparse_categorical_accuracy: 0.5241
# Epoch 19/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2969 - sparse_categorical_accuracy: 0.5375 - val_loss: 1.3576 - val_sparse_categorical_accuracy: 0.5044
# Epoch 20/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2837 - sparse_categorical_accuracy: 0.5441 - val_loss: 1.3768 - val_sparse_categorical_accuracy: 0.5070
# Epoch 21/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2730 - sparse_categorical_accuracy: 0.5435 - val_loss: 1.3229 - val_sparse_categorical_accuracy: 0.5337
# Epoch 22/100
# 675/675 [==============================] - 3s 5ms/step - loss: 1.2656 - sparse_categorical_accuracy: 0.5511 - val_loss: 1.3333 - val_sparse_categorical_accuracy: 0.5204
# Epoch 23/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2624 - sparse_categorical_accuracy: 0.5506 - val_loss: 1.3236 - val_sparse_categorical_accuracy: 0.5248
# Epoch 24/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2468 - sparse_categorical_accuracy: 0.5569 - val_loss: 1.3507 - val_sparse_categorical_accuracy: 0.5170
# Epoch 25/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2405 - sparse_categorical_accuracy: 0.5592 - val_loss: 1.2942 - val_sparse_categorical_accuracy: 0.5415
# Epoch 26/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2252 - sparse_categorical_accuracy: 0.5645 - val_loss: 1.3357 - val_sparse_categorical_accuracy: 0.5207
# Epoch 27/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2164 - sparse_categorical_accuracy: 0.5728 - val_loss: 1.3071 - val_sparse_categorical_accuracy: 0.5367
# Epoch 28/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.2158 - sparse_categorical_accuracy: 0.5658 - val_loss: 1.3162 - val_sparse_categorical_accuracy: 0.5304
# Epoch 29/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.1993 - sparse_categorical_accuracy: 0.5763 - val_loss: 1.2928 - val_sparse_categorical_accuracy: 0.5470
# Epoch 30/100
# 675/675 [==============================] - 3s 5ms/step - loss: 1.2042 - sparse_categorical_accuracy: 0.5726 - val_loss: 1.3017 - val_sparse_categorical_accuracy: 0.5304
# Epoch 31/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1860 - sparse_categorical_accuracy: 0.5802 - val_loss: 1.2890 - val_sparse_categorical_accuracy: 0.5307
# Epoch 32/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1826 - sparse_categorical_accuracy: 0.5780 - val_loss: 1.2891 - val_sparse_categorical_accuracy: 0.5363
# Epoch 33/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1749 - sparse_categorical_accuracy: 0.5817 - val_loss: 1.2723 - val_sparse_categorical_accuracy: 0.5563
# Epoch 34/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1711 - sparse_categorical_accuracy: 0.5861 - val_loss: 1.2718 - val_sparse_categorical_accuracy: 0.5496
# Epoch 35/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1628 - sparse_categorical_accuracy: 0.5897 - val_loss: 1.2680 - val_sparse_categorical_accuracy: 0.5330
# Epoch 36/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1549 - sparse_categorical_accuracy: 0.5900 - val_loss: 1.2688 - val_sparse_categorical_accuracy: 0.5496
# Epoch 37/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1508 - sparse_categorical_accuracy: 0.5915 - val_loss: 1.2737 - val_sparse_categorical_accuracy: 0.5319
# Epoch 38/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1405 - sparse_categorical_accuracy: 0.5967 - val_loss: 1.2556 - val_sparse_categorical_accuracy: 0.5478
# Epoch 39/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1357 - sparse_categorical_accuracy: 0.5977 - val_loss: 1.2368 - val_sparse_categorical_accuracy: 0.5526
# Epoch 40/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1305 - sparse_categorical_accuracy: 0.5999 - val_loss: 1.2487 - val_sparse_categorical_accuracy: 0.5630
# Epoch 41/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1245 - sparse_categorical_accuracy: 0.6022 - val_loss: 1.2437 - val_sparse_categorical_accuracy: 0.5707
# Epoch 42/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1164 - sparse_categorical_accuracy: 0.6062 - val_loss: 1.3102 - val_sparse_categorical_accuracy: 0.5474
# Epoch 43/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1188 - sparse_categorical_accuracy: 0.6028 - val_loss: 1.2624 - val_sparse_categorical_accuracy: 0.5481
# Epoch 44/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1079 - sparse_categorical_accuracy: 0.6094 - val_loss: 1.2746 - val_sparse_categorical_accuracy: 0.5500
# Epoch 45/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1017 - sparse_categorical_accuracy: 0.6085 - val_loss: 1.2835 - val_sparse_categorical_accuracy: 0.5411
# Epoch 46/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1029 - sparse_categorical_accuracy: 0.6096 - val_loss: 1.2513 - val_sparse_categorical_accuracy: 0.5593
# Epoch 47/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0915 - sparse_categorical_accuracy: 0.6150 - val_loss: 1.2570 - val_sparse_categorical_accuracy: 0.5504
# Epoch 48/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0906 - sparse_categorical_accuracy: 0.6190 - val_loss: 1.2318 - val_sparse_categorical_accuracy: 0.5589
# Epoch 49/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0856 - sparse_categorical_accuracy: 0.6191 - val_loss: 1.2584 - val_sparse_categorical_accuracy: 0.5511
# Epoch 50/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0809 - sparse_categorical_accuracy: 0.6164 - val_loss: 1.2568 - val_sparse_categorical_accuracy: 0.5548
# Epoch 51/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0759 - sparse_categorical_accuracy: 0.6194 - val_loss: 1.2213 - val_sparse_categorical_accuracy: 0.5693
# Epoch 52/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0677 - sparse_categorical_accuracy: 0.6250 - val_loss: 1.2295 - val_sparse_categorical_accuracy: 0.5600
# Epoch 53/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0709 - sparse_categorical_accuracy: 0.6206 - val_loss: 1.2200 - val_sparse_categorical_accuracy: 0.5570
# Epoch 54/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0614 - sparse_categorical_accuracy: 0.6256 - val_loss: 1.2614 - val_sparse_categorical_accuracy: 0.5693
# Epoch 55/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0537 - sparse_categorical_accuracy: 0.6296 - val_loss: 1.2116 - val_sparse_categorical_accuracy: 0.5615
# Epoch 56/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0524 - sparse_categorical_accuracy: 0.6293 - val_loss: 1.2333 - val_sparse_categorical_accuracy: 0.5470
# Epoch 57/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0506 - sparse_categorical_accuracy: 0.6298 - val_loss: 1.2249 - val_sparse_categorical_accuracy: 0.5689
# Epoch 58/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0442 - sparse_categorical_accuracy: 0.6324 - val_loss: 1.2183 - val_sparse_categorical_accuracy: 0.5648
# Epoch 59/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0392 - sparse_categorical_accuracy: 0.6363 - val_loss: 1.2411 - val_sparse_categorical_accuracy: 0.5626
# Epoch 60/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0336 - sparse_categorical_accuracy: 0.6360 - val_loss: 1.2077 - val_sparse_categorical_accuracy: 0.5744
# Epoch 61/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0320 - sparse_categorical_accuracy: 0.6412 - val_loss: 1.2138 - val_sparse_categorical_accuracy: 0.5644
# Epoch 62/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0331 - sparse_categorical_accuracy: 0.6396 - val_loss: 1.2117 - val_sparse_categorical_accuracy: 0.5593
# Epoch 63/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0242 - sparse_categorical_accuracy: 0.6412 - val_loss: 1.2090 - val_sparse_categorical_accuracy: 0.5667
# Epoch 64/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0175 - sparse_categorical_accuracy: 0.6431 - val_loss: 1.1982 - val_sparse_categorical_accuracy: 0.5730
# Epoch 65/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0143 - sparse_categorical_accuracy: 0.6456 - val_loss: 1.2221 - val_sparse_categorical_accuracy: 0.5670
# Epoch 66/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0096 - sparse_categorical_accuracy: 0.6483 - val_loss: 1.2262 - val_sparse_categorical_accuracy: 0.5744
# Epoch 67/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0091 - sparse_categorical_accuracy: 0.6451 - val_loss: 1.2193 - val_sparse_categorical_accuracy: 0.5696
# Epoch 68/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0059 - sparse_categorical_accuracy: 0.6477 - val_loss: 1.2262 - val_sparse_categorical_accuracy: 0.5637
# Epoch 69/100
# 675/675 [==============================] - 3s 4ms/step - loss: 1.0024 - sparse_categorical_accuracy: 0.6538 - val_loss: 1.1838 - val_sparse_categorical_accuracy: 0.5811
# Epoch 70/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9944 - sparse_categorical_accuracy: 0.6534 - val_loss: 1.1900 - val_sparse_categorical_accuracy: 0.5652
# Epoch 71/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9970 - sparse_categorical_accuracy: 0.6516 - val_loss: 1.2368 - val_sparse_categorical_accuracy: 0.5711
# Epoch 72/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9946 - sparse_categorical_accuracy: 0.6523 - val_loss: 1.2286 - val_sparse_categorical_accuracy: 0.5596
# Epoch 73/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9841 - sparse_categorical_accuracy: 0.6581 - val_loss: 1.2001 - val_sparse_categorical_accuracy: 0.5741
# Epoch 74/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9863 - sparse_categorical_accuracy: 0.6570 - val_loss: 1.1994 - val_sparse_categorical_accuracy: 0.5752
# Epoch 75/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9814 - sparse_categorical_accuracy: 0.6576 - val_loss: 1.1944 - val_sparse_categorical_accuracy: 0.5678
# Epoch 76/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9766 - sparse_categorical_accuracy: 0.6580 - val_loss: 1.1935 - val_sparse_categorical_accuracy: 0.5759
# Epoch 77/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9734 - sparse_categorical_accuracy: 0.6593 - val_loss: 1.1932 - val_sparse_categorical_accuracy: 0.5785
# Epoch 78/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9681 - sparse_categorical_accuracy: 0.6637 - val_loss: 1.2007 - val_sparse_categorical_accuracy: 0.5693
# Epoch 79/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9677 - sparse_categorical_accuracy: 0.6644 - val_loss: 1.2015 - val_sparse_categorical_accuracy: 0.5837
# Epoch 80/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9705 - sparse_categorical_accuracy: 0.6614 - val_loss: 1.1742 - val_sparse_categorical_accuracy: 0.5748
# Epoch 81/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9582 - sparse_categorical_accuracy: 0.6672 - val_loss: 1.2176 - val_sparse_categorical_accuracy: 0.5644
# Epoch 82/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9624 - sparse_categorical_accuracy: 0.6672 - val_loss: 1.1846 - val_sparse_categorical_accuracy: 0.5704
# Epoch 83/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9542 - sparse_categorical_accuracy: 0.6678 - val_loss: 1.1937 - val_sparse_categorical_accuracy: 0.5741
# Epoch 84/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9529 - sparse_categorical_accuracy: 0.6691 - val_loss: 1.1727 - val_sparse_categorical_accuracy: 0.5878
# Epoch 85/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9498 - sparse_categorical_accuracy: 0.6708 - val_loss: 1.1979 - val_sparse_categorical_accuracy: 0.5670
# Epoch 86/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9480 - sparse_categorical_accuracy: 0.6694 - val_loss: 1.2098 - val_sparse_categorical_accuracy: 0.5830
# Epoch 87/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9410 - sparse_categorical_accuracy: 0.6749 - val_loss: 1.1779 - val_sparse_categorical_accuracy: 0.5715
# Epoch 88/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9430 - sparse_categorical_accuracy: 0.6756 - val_loss: 1.1782 - val_sparse_categorical_accuracy: 0.5807
# Epoch 89/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9390 - sparse_categorical_accuracy: 0.6740 - val_loss: 1.1743 - val_sparse_categorical_accuracy: 0.5811
# Epoch 90/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9345 - sparse_categorical_accuracy: 0.6791 - val_loss: 1.1798 - val_sparse_categorical_accuracy: 0.5748
# Epoch 91/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9348 - sparse_categorical_accuracy: 0.6762 - val_loss: 1.1752 - val_sparse_categorical_accuracy: 0.5722
# Epoch 92/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9316 - sparse_categorical_accuracy: 0.6819 - val_loss: 1.1768 - val_sparse_categorical_accuracy: 0.5826
# Epoch 93/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9285 - sparse_categorical_accuracy: 0.6809 - val_loss: 1.1643 - val_sparse_categorical_accuracy: 0.5841
# Epoch 94/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9236 - sparse_categorical_accuracy: 0.6800 - val_loss: 1.1834 - val_sparse_categorical_accuracy: 0.5885
# Epoch 95/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9259 - sparse_categorical_accuracy: 0.6813 - val_loss: 1.2028 - val_sparse_categorical_accuracy: 0.5837
# Epoch 96/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9191 - sparse_categorical_accuracy: 0.6850 - val_loss: 1.1803 - val_sparse_categorical_accuracy: 0.5830
# Epoch 97/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9199 - sparse_categorical_accuracy: 0.6860 - val_loss: 1.2132 - val_sparse_categorical_accuracy: 0.5733
# Epoch 98/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9200 - sparse_categorical_accuracy: 0.6850 - val_loss: 1.1755 - val_sparse_categorical_accuracy: 0.5770
# Epoch 99/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9155 - sparse_categorical_accuracy: 0.6853 - val_loss: 1.2050 - val_sparse_categorical_accuracy: 0.5830
# Epoch 100/100
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9115 - sparse_categorical_accuracy: 0.6900 - val_loss: 1.1803 - val_sparse_categorical_accuracy: 0.5930

# %% [markdown]
# 17. Save your model as ```my_first_model.h5```.

# %%
# your code
model.save('my_first_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# 18. Execute the following code to load your model again (this can be helpful if you pause and want to continue later).

# %%
# your code
new_model = tf.keras.models.load_model('my_first_model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# **Checkpoint:** You should have been able to save and load your model again.

# %% [markdown]
# ### Learning curves
#
# The return value of ```model.fit``` is an object ```history``` of type ```keras.callbacks.History```. This object features attributes ```history.history``` and ```history.params```. The former is a dictionary with keys ```"loss"```, ```"sparse_categorical_accuracy"```, ```"val_loss"```, and ```"val_sparse_categorical_accuracy"```. The associated values are lists containing the respective metrics computed towards the end of each epoch.
#
# 19. Construct an object ```history_frame``` of class ```pd.DataFrame``` from ```history.history```. Call ```history_frame.plot(figsize=(8, 5))``` and afterwards ```plt.show()```.
#
# Write your code below the two lines at the top of the following cell. The usage of ```seaborn``` here only provides a standardized and relatively pleasing style and rendering of the plots.

# %%
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set_context("notebook")

# your code

history_frame = pd.DataFrame(history.history)
history_frame.plot(figsize=(8, 5))
plt.show()

# %% [markdown]
# ### Model evaluation
#
# During training, you could already watch the values of ```loss```, ```sparse_categorical_accuracy```, ```val_loss``` and ```sparse_categorical_val_accuracy``` evolve. To evaluate your model manually on a dataset, you can also call ```model.evaluate```.
#
# 20. Apply ```model.evaluate``` twice to evaluate your model on training and validation data.

# %%
# your code
val_eval = model.evaluate(val_ds, batch_size=batch_size)
val_eval
# Out:
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1803 - sparse_categorical_accuracy: 0.5930
# [1.1802998781204224, 0.5929629802703857]

# %%
test_eval = model.evaluate(test_ds, batch_size=batch_size)
test_eval
# Out:
# 2700/2700 [==============================] - 5s 2ms/step - loss: 1.1848 - sparse_categorical_accuracy: 0.6000
# [1.1848268508911133, 0.6000000238418579]

# %% [markdown]
# ***Congratulations!***
#
# You have trained a first model for multiclass classification on ```EUROSAT``` and that is an important milestone!

# %% [markdown]
# ## 1.3 After training
#
# Apart from the model architecture and the observed metrics ```loss```, ```sparse_categorical_accuracy```, ```val_loss``` and ```val_sparse_categorical_accuracy```, we know yet only little about the functionality of our model. In this section, you will get to know two techniques for model visualization and interpretation.

# %% [markdown]
# ### Forward propagation and model prediction
#
# Before we proceed to a first visualization technique, we recapitulate the forward propagation of an input image through a fully connected neural network. For a model with one $\mathrm{ReLU}$ hidden layer and $\mathrm{softmax}$ output layer, the forward mapping can be written as follows.
#
# $f(\mathbf x) = \underbrace{\mathrm{softmax}(\mathbf W^{[2]} \underbrace{\mathrm{ReLU}(\mathbf W^{[1]}\mathbf x + \mathbf b^{[1]})}_{\mathbf a^{[1]}} + \mathbf b^{[2]})}_{\mathbf a^{[2]}}$
#
# As a first step, we will now compute $f(\mathbf x)$ using ```model```. The fastest way to do so is generally via the method ```model.predict```. However, just once, we will evaluate each layer of ```model``` separately to compute the network output. You can access the layers via ```model.layers[i]``` and use this object like a function.
#
# 21. Complete the following code where indicated. The variable ```output``` shall ultimately contain $f(\mathbf x)$ while ```prediction``` shall be a single number representing the predicted class.

# %%
# get one batch from train_ds and select first item
for item in train_ds.take(1):
    demo_image = item[0][:1, ...]
    demo_label = item[1][0]

# compute hidden activations, model output and predicted_label
flattened_input = model.layers[0]  # your code
hidden_activations = model.layers[1]  # your code
output = model.predict(demo_image)  # your code
predicted_label = demo_label  # your code


# plot demo_image, print demo_label
plt.imshow(demo_image[0, ...], cmap="gray")
plt.xticks([])
plt.yticks([])
plt.xlabel("Input demo_image")
plt.show()
print(f'True label: {demo_label} ({info.features["label"].names[demo_label]})\n')

# print my predicted class probabilities and demo_label
print("My Predicted Class Probabilities:\n")
for i in range(output.shape[1]):
    print(f"{i}: {output[0][i]:.5f}")
print(
    f'\nMy Predicted label: {predicted_label} ({info.features["label"].names[predicted_label]})'
)

# print model predicted class probabilities
model_output = model.predict(demo_image)
print("\nModel Predicted Class Probabilities:\n")
for i in range(model_output.shape[1]):
    print(f"{i}: {model_output[0][i]:.5f}")
# Out:
# 1/1 [==============================] - 0s 42ms/step
# True label: 7 (Residential)
#
# My Predicted Class Probabilities:
#
# 0: 0.08437
# 1: 0.00000
# 2: 0.09763
# 3: 0.05131
# 4: 0.03166
# 5: 0.00830
# 6: 0.10563
# 7: 0.55100
# 8: 0.00579
# 9: 0.06433
#
# My Predicted label: 7 (Residential)
# 1/1 [==============================] - 0s 18ms/step
#
# Model Predicted Class Probabilities:
#
# 0: 0.08437
# 1: 0.00000
# 2: 0.09763
# 3: 0.05131
# 4: 0.03166
# 5: 0.00830
# 6: 0.10563
# 7: 0.55100
# 8: 0.00579
# 9: 0.06433

# %% [markdown]
# **Checkpoint:** The values ```My Predicted Class Probabilities``` should be equal to ```Model Predicted Class Probabilities```. Moreover, the value ```My Predicted Label``` should correspond to the index of the largest entry of ```My Predicted Class Probabilities```.

# %% [markdown]
# ### Interpretation of model predictions
#
# Now that we have visualized the connection between model parameters and activations, we will implement another method to explain the relation between model input and prediction: *Layer-Wise Relevance Propagation* (LRP) computes one so-called relevance score per input pixel, which can be considered the contribution of that pixel to the model prediction. To that end, relevance scores for all neurons in the network are successively generated via backpropagation from the output layer to the input layer.
#
# Relevance scores for the ouput layer are initially defined using the model output (i.e., the predicted probability) corresponding to ```predicted_label``` ($k$ represents the respective index here):
#
# $\mathbf r^{[L]} := \begin{pmatrix}0\\\vdots\\\mathbf a^{[L]}_k\\\vdots\\0\end{pmatrix}\in \mathbb R^{n_L}$
#
# Afterwards, relevance scores $\mathbf r^{[L-1]}, \mathbf r^{[L-2]}, \dots, \mathbf r^{[1]}, \mathbf r^{[0]}$ (in exactly this order) are computed for all other layers as follows:
#
# $\displaystyle \mathbf r^{[\ell-1]} := \alpha \ \frac{\mathbf a^{[\ell -1]}\odot \mathbf W^{[\ell]\top+}}{\mathbf a^{[\ell -1]\top} \mathbf W^{[\ell]\top+}} \ \mathbf r^{[\ell]} \ - \ \beta \ \frac{\mathbf a^{[\ell -1]}\odot \mathbf W^{[\ell]\top-}}{\mathbf a^{[\ell -1]\top} \mathbf W^{[\ell]\top-}} \ \mathbf r^{[\ell]}$
#
# Therein
#
# $\mathbf W^{[\ell]\top+} := \max(\mathbf W^{[\ell]\top}, \mathbf 0)$
#
# denotes the positive part and
#
# $\mathbf W^{[\ell]\top-} := -\min(\mathbf W^{[\ell]\top}, \mathbf 0)$
#
# denotes the negative part of $\mathbf W^{[\ell]\top} \in \mathbb R^{n_{\ell-1}\times n_{\ell}}$, where minimum and maximum are computed componentwise. Moreover,
#
# $\mathbf a^{[\ell -1]}\odot \mathbf W^{[\ell]\top+}\in \mathbb R^{n_{\ell-1}\times n_{\ell}}$
#
# results from componentwise multiplication of $\mathbf a^{[\ell -1]}\in \mathbb R^{n_{\ell-1}}$ with each column of $\mathbf W^{[\ell]\top+}$ (same for the negative part). Analogously, the fraction line stands for componentwise division of the rows of $\mathbf a^{[\ell -1]}\odot \mathbf W^{[\ell]\top+}$ by $\mathbf a^{[\ell -1]\top} \mathbf W^{[\ell]\top+}\in \mathbb R^{1\times n_{\ell}}$ (same for the other fraction). Consequently, each fraction represents a $n_{\ell-1}\times n_{\ell}$ matrix which is then multiplied with $\mathbf r^{[\ell]}\in \mathbb R^{n_{\ell}\times 1}$.
#
# The scalar values $\alpha, \beta \geq 0$ are chosen such that $\alpha - \beta = 1$. Therewith, it can be shown that
#
# $\sum_j \mathbf r^{[L]}_j = \sum_j \mathbf r^{[L-1]}_j = \sum_j \mathbf r^{[L-2]}_j = \dots = \sum_j \mathbf r^{[1]}_j = \sum_j \mathbf r^{[0]}_j$
#
# holds. Therefore, LRP has a so-called *relevance conservation property*.
#
# The above formulas are kept as brief as possible. However, they have a concrete interpretation: Each neuron in a layer contributes positively or negatively to all neuron activations in successive layers. The relevance score of a neuron can be considered a proportionate sum of these contributions, and that is exactly reflected in the above formulas.
#
# If you have questions regarding LRP or want to know more about it, join Question Time or have a look at https://www.sciencedirect.com/science/article/pii/S1051200417302385?via%3Dihub.
#
# Here is your exercise:
#
# 22. Complete the following function at the positions indicated by ```None``` such that it fits exactly with the above LRP formula. Again, be aware that ```model.layers[l].weights[0]``` corresponds to $\mathbf W^{[\ell]\top}$. If you are unsure about shapes or dimensions of tensors, you can use ```tf.Tensor.shape``` to generate intermediate outputs. Also note that the function ```LRP``` should work for arbitrarily deep and wide fully connected $\mathrm{ReLU}$ networks with $\mathrm{softmax}$ output activation.

# %%
def lrp(alpha, beta, model, x):

    # get number of layers (including input layer)
    num_layers = len(model.layers)
    print(num_layers)

    # get activations
    activations = [model.layers[0](x)]
    for l in range(1, num_layers):
        activations.append(model.layers[l](activations[-1]))

    # compute scores
    scores = [tf.transpose(activations[-1])]
    #     print(scores)
    #     print("@@@@")
    c = tf.squeeze(tf.math.argmax(scores[0]))
    #     print(c)
    #     print("@@@@")
    for l in range(num_layers - 2, -1, -1):
        w = model.layers[l + 1].weights[0]
        if l == num_layers - 2:
            w_pos = tf.clip_by_value(w[:, c : c + 1], 0, np.inf)
            w_neg = -tf.clip_by_value(w[:, c : c + 1], -np.inf, 0)
            s = scores[0][c : c + 1]
            scores[0] = s
        else:
            w_pos = tf.clip_by_value(w, 0, np.inf)
            w_neg = -tf.clip_by_value(w, -np.inf, 0)
            s = scores[0]
        a = activations[l]
        print(a)

        # use the following mask_pos and mask_neg to prevent from division by zero when computing score_pos and score_neg
        mask_pos = tf.cast(tf.matmul(a, w_pos) == 0, tf.float32) + 1e-6
        mask_neg = tf.cast(tf.matmul(a, w_neg) == 0, tf.float32) + 1e-6
        #         print(mask_pos)

        #         score_pos = alpha * (tf.matmul(a * tf.transpose(w_pos), s))
        #         score_pos = beta * (tf.matmul(a * tf.transpose(w_neg), s))

        score_pos = alpha*tf((tf.transpose(a)* w_pos) / (a * w_pos + mask_pos),s)  # your code
        score_neg = tf.tensordot(tf.transpose(a), w_neg, 1, name=None) / (
            tf.transpose(a) * w_neg + mask_neg
        )  # your code

        score_total = alpha * (tf.matmul(score_pos, s)) - beta * (
            tf.matmul(score_neg, s)
        )  # your code

        scores.insert(0, score_total)

    return scores, activations

# %%
print(1e-6)
# Out:
# 1e-06

# %% [markdown]
# 23. Apply LRP with $\alpha=2$ and $\beta=1$ to ```model``` and ```demo_image```.

# %%
# you can uncomment the following three lines to try demo_image / demo_label other than the above-defined
for item in train_ds.take(1):
    demo_image = item[0][:1, ...]
    demo_label = item[1][0]

scores, _ = lrp(2, 1, model, demo_image)  # your code
scores_input = scores[0].numpy().reshape(64, 64, 3)

print("Predicted Probability for Predicted Class (Relevance in Output Layer):\n")
print(f"{tf.squeeze(scores[-1]).numpy():.5f}\n")

print("\nSum of all Relevances in Input Layer:\n")
print(f"{tf.squeeze(tf.reduce_sum(scores[0])).numpy():.5f}\n")

print("\nTrue Class\n")
print(f'{demo_label} ({info.features["label"].names[demo_label]})\n')

prediction = model.predict(demo_image)
predicted_label = np.argmax(prediction)
print("\nPredicted Class\n")
print(
    f'{predicted_label} ({info.features["label"].names[predicted_label]}) with probability {prediction[0][predicted_label]}\n'
)

plt.subplots(1, 2, figsize=(12, 6.75))
plt.subplot(1, 2, 1)
plt.imshow(demo_image[0, ...], norm=mcolors.TwoSlopeNorm(vcenter=0.5))
plt.xticks([])
plt.yticks([])
plt.subplot(1, 2, 2)
tmp = np.sum(scores_input, axis=2)
min_score = tmp.min()
max_score = tmp.max()
tmp = (tmp - min_score) / (max_score - min_score)
plt.imshow(
    tmp,
    cmap=plt.cm.seismic,
    norm=mcolors.TwoSlopeNorm(vcenter=-min_score / (max_score - min_score)),
    alpha=1.0,
)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 3
# tf.Tensor(
# [[0.         0.00571591 0.         0.         0.4549043  0.
#   0.35270154 0.14256012 0.13013157 0.5159099  0.05688483 0.
#   0.5810369  0.         0.22896297 0.16440924 0.5252737  0.
#   0.44710022 0.         0.         0.06761043 0.         0.01478496
#   0.6206488  0.57439125 0.         0.         0.21871994 0.
#   0.9733068  0.         0.         0.9626458  0.05662811 0.
#   0.         1.0660686  0.         0.         0.         0.05567493
#   0.24706252 0.3892388  0.5443677  0.14790422 0.65285444 0.
#   0.13845545 0.         0.         0.02534533 0.         0.
#   0.         0.         0.         0.15678777 0.47180182 0.
#   0.         0.7511685  0.         0.         0.7007072  0.00245288
#   0.75606704 0.         0.         0.         0.5461717  0.9729826
#   0.21773806 1.5246017  0.         0.         0.         0.16943687
#   0.         0.25205213 0.         0.0895355  1.1042141  0.
#   0.01289724 0.11607051 0.         0.         0.         0.7443409
#   0.         0.65088785 0.         0.06807646 0.         0.
#   0.         0.         0.         0.         0.3823058  1.201782
#   0.23254935 0.         0.         0.         0.80280644 0.39638424
#   0.76324713 0.         0.25035846 0.88276535 0.4331916  0.41821587
#   0.         0.39109614 0.         0.         1.1029245  0.21401183
#   1.814015   0.51802504 0.         0.         0.38453156 0.62333137
#   0.         0.23891516 0.05285895 0.         0.31174535 0.5101933
#   0.37751982 0.         0.         0.         0.5442312  1.5005488
#   0.39590117 1.3729668  0.         0.         0.         0.36428863
#   0.         0.18674646 0.         0.12714007 0.         0.31733254
#   0.7799993  0.         0.71774495 0.         0.609919   0.
#   0.         0.         1.0251554  0.         0.         0.
#   0.14039493 0.3843919  0.         0.         0.3681236  0.0828792
#   0.36029485 0.257234   0.         0.07062185 0.25855592 0.
#   0.2468442  0.         0.         0.         1.4215853  0.2745643
#   0.97181094 0.5953733  0.         0.03037092 0.         0.05819832
#   0.         0.         0.         0.         0.         0.12126601
#   0.1982471  0.         0.15691188 0.8211062  0.62000674 0.13483715
#   0.         0.         0.17296506 0.         0.         0.
#   0.         0.27826992 0.         0.         0.         0.55215514
#   0.1451643  0.         0.         0.6863917  0.         0.787735
#   0.37459856 0.25291285 0.41815743 0.00494854 0.         0.26161432
#   0.         0.         0.         0.26215512 0.         0.
#   0.3057549  0.         0.         0.07163462 0.         0.
#   0.         0.         0.24582383 1.6325955  0.7602995  0.59081495
#   1.114249   0.         0.         0.15136799 0.7369394  0.2735737
#   0.51149607 0.24983399 0.         0.29498887 0.         1.131673
#   0.         0.         0.09505452 0.38332868]], shape=(1, 256), dtype=float32)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In [56], line 6
#       3     demo_image = item[0][:1, ...]
#       4     demo_label = item[1][0]
# ----> 6 scores, _ = lrp(2, 1, model, demo_image)  # your code
#       7 scores_input = scores[0].numpy().reshape(64, 64, 3)
#       9 print("Predicted Probability for Predicted Class (Relevance in Output Layer):\n")
#
# Cell In [54], line 41, in lrp(alpha, beta, model, x)
#      35 mask_neg = tf.cast(tf.matmul(a, w_neg) == 0, tf.float32) + 1e-6
#      36 #         print(mask_pos)
#      37
#      38 #         score_pos = alpha * (tf.matmul(a * tf.transpose(w_pos), s))
#      39 #         score_pos = beta * (tf.matmul(a * tf.transpose(w_neg), s))
# ---> 41 score_pos = tf.tensordot(tf.transpose(a), w_pos, 1, name=None) / (
#      42     tf.transpose(a) * w_pos + mask_pos
#      43 )  # your code
#      44 score_neg = tf.tensordot(tf.transpose(a), w_neg, 1, name=None) / (
#      45     tf.transpose(a) * w_neg + mask_neg
#      46 )  # your code
#      48 score_total = alpha * (tf.matmul(score_pos, s)) - beta * (
#      49     tf.matmul(score_neg, s)
#      50 )  # your code
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py:7209, in raise_from_not_ok_status(e, name)
#    7207 def raise_from_not_ok_status(e, name):
#    7208   e.message += (" name: " + name if name is not None else "")
# -> 7209   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: {{function_node __wrapped__MatMul_device_/job:localhost/replica:0/task:0/device:GPU:0}} Matrix size-incompatible: In[0]: [256,1], In[1]: [256,1] [Op:MatMul]

# %% [markdown]
# **Checkpoint**: Both displayed numbers should be equal if your implementation of LRP is correct (otherwise, your implementation does not obey the relevance conservation property).

# %% [markdown]
# ### Hyperparameter Tuning
#
# Your first model had only one hidden layer and a very small number of neurons. In this section, you will train many more models to find a configuration of *hyperparameters* that yield a much better performance on the validation data. Although there exist dedicated approaches and software to explore the space of hyperparameters, we will start with simple nested ```for``` loops. This is for certain not the most efficient among the available approaches, which is why you should carry out the following computation on the GPU-cluster. You may extend the hyperparameter configurations specified below to extend the search space.
#
# 24. Understand and complete the following code and discuss it with your teammate. Execute the code on the GPU-cluster.

# %%
results = pd.DataFrame(
    columns=[
        "start_learning_rate",
        "width",
        "depth",
        "l2_weight",
        "train_loss",
        "val_loss",
        "train_acc",
        "val_acc",
    ]
)

start_learning_rates = [1e-5, 1e-4, 1e-3]
widths = [256, 512, 1024]
depths = [1, 2, 3]
l2_weights = [0, 1e-5, 1e-4]

for start_learning_rate in start_learning_rates:
    for width in widths:
        for depth in depths:
            for l2_weight in l2_weights:
                model = keras.models.Sequential()
                # your code (add input layer)
                model.add(
                    tf.keras.layers.InputLayer(input_shape=info.features["image"].shape)
                )
                model.add(tf.keras.layers.Flatten())
                for _ in range(depth):
                    model.add(
                        keras.layers.Dense(
                            units=width,
                            activation="relu",
                            kernel_regularizer=keras.regularizers.l2(l2_weight),
                        )
                    )
                # your code (add output layer)
                model.add(
                    tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)
                )
                scheduler = tf.keras.optimizers.schedules.PolynomialDecay(
                    start_learning_rate,
                    epochs * sum(train_occurences) // batch_size,
                    1e-8,
                    power=1.0,
                )
                model.compile(
                    loss=keras.losses.sparse_categorical_crossentropy,
                    optimizer=keras.optimizers.Adam(learning_rate=scheduler),
                    metrics=[keras.metrics.sparse_categorical_accuracy],
                )
                # your code (call fit function with verbose=0)
                model.fit(
                    train_ds,
                    epochs=epochs,
                    steps_per_epoch=np.ceil(sum(train_occurences) / batch_size),
                    validation_data=val_ds,
                    verbose=0,
                )
                train_loss, train_acc = model.evaluate(
                    train_ds, steps=np.sum(train_occurences) // batch_size
                )
                val_loss, val_acc = model.evaluate(val_ds)
                results_tmp = np.array(
                    [
                        start_learning_rate,
                        width,
                        depth,
                        l2_weight,
                        train_loss,
                        val_loss,
                        train_acc,
                        val_acc,
                    ]
                ).reshape(1, -1)
                results = results.append(
                    pd.DataFrame(data=results_tmp, columns=results.columns),
                    ignore_index=True,
                )
results.to_csv("results.csv")
# Out:
# 675/675 [==============================] - 2s 3ms/step - loss: 1.2423 - sparse_categorical_accuracy: 0.5791
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3284 - sparse_categorical_accuracy: 0.5333
# C:\Users\psraj\AppData\Local\Temp\ipykernel_12432\4228535109.py:76: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(
# 675/675 [==============================] - 2s 3ms/step - loss: 1.2410 - sparse_categorical_accuracy: 0.5825
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3316 - sparse_categorical_accuracy: 0.5333
# 675/675 [==============================] - 2s 3ms/step - loss: 1.2631 - sparse_categorical_accuracy: 0.5823
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3547 - sparse_categorical_accuracy: 0.5352
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1123 - sparse_categorical_accuracy: 0.6143
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2221 - sparse_categorical_accuracy: 0.5559
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0946 - sparse_categorical_accuracy: 0.6259
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2172 - sparse_categorical_accuracy: 0.5719
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1431 - sparse_categorical_accuracy: 0.6244
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2582 - sparse_categorical_accuracy: 0.5693
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0730 - sparse_categorical_accuracy: 0.6252
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1849 - sparse_categorical_accuracy: 0.5770
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0817 - sparse_categorical_accuracy: 0.6247
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1932 - sparse_categorical_accuracy: 0.5781
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1443 - sparse_categorical_accuracy: 0.6204
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2470 - sparse_categorical_accuracy: 0.5759
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1381 - sparse_categorical_accuracy: 0.6214
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2591 - sparse_categorical_accuracy: 0.5630
# 675/675 [==============================] - 3s 4ms/step - loss: 1.1330 - sparse_categorical_accuracy: 0.6223
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2603 - sparse_categorical_accuracy: 0.5544
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1877 - sparse_categorical_accuracy: 0.6236
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3118 - sparse_categorical_accuracy: 0.5678
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9645 - sparse_categorical_accuracy: 0.6737
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1381 - sparse_categorical_accuracy: 0.5970
# 675/675 [==============================] - 2s 4ms/step - loss: 0.9869 - sparse_categorical_accuracy: 0.6695
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1494 - sparse_categorical_accuracy: 0.6022
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0729 - sparse_categorical_accuracy: 0.6667
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2296 - sparse_categorical_accuracy: 0.6004
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9068 - sparse_categorical_accuracy: 0.6888
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0781 - sparse_categorical_accuracy: 0.6144
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9045 - sparse_categorical_accuracy: 0.6913
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0944 - sparse_categorical_accuracy: 0.6156
# 675/675 [==============================] - 2s 4ms/step - loss: 1.0079 - sparse_categorical_accuracy: 0.6866
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1853 - sparse_categorical_accuracy: 0.6207
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0609 - sparse_categorical_accuracy: 0.6517
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2141 - sparse_categorical_accuracy: 0.5700
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0711 - sparse_categorical_accuracy: 0.6519
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2317 - sparse_categorical_accuracy: 0.5685
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1726 - sparse_categorical_accuracy: 0.6566
# 85/85 [==============================] - 0s 3ms/step - loss: 1.3303 - sparse_categorical_accuracy: 0.5778
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7989 - sparse_categorical_accuracy: 0.7345
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0374 - sparse_categorical_accuracy: 0.6407
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8211 - sparse_categorical_accuracy: 0.7371
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0641 - sparse_categorical_accuracy: 0.6359
# 675/675 [==============================] - 3s 4ms/step - loss: 0.9662 - sparse_categorical_accuracy: 0.7364
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2037 - sparse_categorical_accuracy: 0.6333
# 675/675 [==============================] - 3s 4ms/step - loss: 0.6490 - sparse_categorical_accuracy: 0.7823
# 85/85 [==============================] - 0s 3ms/step - loss: 0.9587 - sparse_categorical_accuracy: 0.6685
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6788 - sparse_categorical_accuracy: 0.7792
# 85/85 [==============================] - 0s 3ms/step - loss: 0.9878 - sparse_categorical_accuracy: 0.6652
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8763 - sparse_categorical_accuracy: 0.7793
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1779 - sparse_categorical_accuracy: 0.6733
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0381 - sparse_categorical_accuracy: 0.6423
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2422 - sparse_categorical_accuracy: 0.5663
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9823 - sparse_categorical_accuracy: 0.6673
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1914 - sparse_categorical_accuracy: 0.5819
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9769 - sparse_categorical_accuracy: 0.6803
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1972 - sparse_categorical_accuracy: 0.5919
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7367 - sparse_categorical_accuracy: 0.7468
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0358 - sparse_categorical_accuracy: 0.6467
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7370 - sparse_categorical_accuracy: 0.7517
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0333 - sparse_categorical_accuracy: 0.6437
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7549 - sparse_categorical_accuracy: 0.7519
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0621 - sparse_categorical_accuracy: 0.6437
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5503 - sparse_categorical_accuracy: 0.8144
# 85/85 [==============================] - 0s 2ms/step - loss: 0.9665 - sparse_categorical_accuracy: 0.6696
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5810 - sparse_categorical_accuracy: 0.8067
# 85/85 [==============================] - 0s 2ms/step - loss: 0.9833 - sparse_categorical_accuracy: 0.6752
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6188 - sparse_categorical_accuracy: 0.8068
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0145 - sparse_categorical_accuracy: 0.6796
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8902 - sparse_categorical_accuracy: 0.6971
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1275 - sparse_categorical_accuracy: 0.6078
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9023 - sparse_categorical_accuracy: 0.6960
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1483 - sparse_categorical_accuracy: 0.6037
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9387 - sparse_categorical_accuracy: 0.6936
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1802 - sparse_categorical_accuracy: 0.6074
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5842 - sparse_categorical_accuracy: 0.8051
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0106 - sparse_categorical_accuracy: 0.6644
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6050 - sparse_categorical_accuracy: 0.8006
# 85/85 [==============================] - 0s 3ms/step - loss: 0.9960 - sparse_categorical_accuracy: 0.6637
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6540 - sparse_categorical_accuracy: 0.7974
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0380 - sparse_categorical_accuracy: 0.6659
# 675/675 [==============================] - 2s 3ms/step - loss: 0.3851 - sparse_categorical_accuracy: 0.8789
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0216 - sparse_categorical_accuracy: 0.6915
# 675/675 [==============================] - 2s 3ms/step - loss: 0.4146 - sparse_categorical_accuracy: 0.8708
# 85/85 [==============================] - 0s 2ms/step - loss: 0.9931 - sparse_categorical_accuracy: 0.6956
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5065 - sparse_categorical_accuracy: 0.8618
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0475 - sparse_categorical_accuracy: 0.6922
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8564 - sparse_categorical_accuracy: 0.7096
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1168 - sparse_categorical_accuracy: 0.6022
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8406 - sparse_categorical_accuracy: 0.7197
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1173 - sparse_categorical_accuracy: 0.6141
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9073 - sparse_categorical_accuracy: 0.7098
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1596 - sparse_categorical_accuracy: 0.6096
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5158 - sparse_categorical_accuracy: 0.8331
# 85/85 [==============================] - 0s 2ms/step - loss: 0.9842 - sparse_categorical_accuracy: 0.6785
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5028 - sparse_categorical_accuracy: 0.8394
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0230 - sparse_categorical_accuracy: 0.6737
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5595 - sparse_categorical_accuracy: 0.8402
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0613 - sparse_categorical_accuracy: 0.6726
# 675/675 [==============================] - 2s 3ms/step - loss: 0.2611 - sparse_categorical_accuracy: 0.9223
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1664 - sparse_categorical_accuracy: 0.6893
# 675/675 [==============================] - 2s 3ms/step - loss: 0.3007 - sparse_categorical_accuracy: 0.9138
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1278 - sparse_categorical_accuracy: 0.6889
# 675/675 [==============================] - 2s 3ms/step - loss: 0.4228 - sparse_categorical_accuracy: 0.8971
# 85/85 [==============================] - 0s 3ms/step - loss: 1.1254 - sparse_categorical_accuracy: 0.6922
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1412 - sparse_categorical_accuracy: 0.5970
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3646 - sparse_categorical_accuracy: 0.5396
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9659 - sparse_categorical_accuracy: 0.6661
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2175 - sparse_categorical_accuracy: 0.5900
# 675/675 [==============================] - 2s 3ms/step - loss: 1.1532 - sparse_categorical_accuracy: 0.6037
# 85/85 [==============================] - 0s 2ms/step - loss: 1.3110 - sparse_categorical_accuracy: 0.5441
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7643 - sparse_categorical_accuracy: 0.7255
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0659 - sparse_categorical_accuracy: 0.6437
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7089 - sparse_categorical_accuracy: 0.7528
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0219 - sparse_categorical_accuracy: 0.6600
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.7286
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0554 - sparse_categorical_accuracy: 0.6511
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5396 - sparse_categorical_accuracy: 0.8079
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0637 - sparse_categorical_accuracy: 0.6759
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5462 - sparse_categorical_accuracy: 0.8095
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0917 - sparse_categorical_accuracy: 0.6707
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6747 - sparse_categorical_accuracy: 0.7780
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0510 - sparse_categorical_accuracy: 0.6670
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9381 - sparse_categorical_accuracy: 0.6667
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2198 - sparse_categorical_accuracy: 0.5804
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9550 - sparse_categorical_accuracy: 0.6721
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2070 - sparse_categorical_accuracy: 0.5896
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0691 - sparse_categorical_accuracy: 0.6409
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2586 - sparse_categorical_accuracy: 0.5796
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.7198
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0628 - sparse_categorical_accuracy: 0.6456
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7295 - sparse_categorical_accuracy: 0.7417
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0358 - sparse_categorical_accuracy: 0.6537
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7567 - sparse_categorical_accuracy: 0.7421
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0441 - sparse_categorical_accuracy: 0.6637
# 675/675 [==============================] - 2s 3ms/step - loss: 0.4886 - sparse_categorical_accuracy: 0.8253
# 85/85 [==============================] - 0s 2ms/step - loss: 1.1411 - sparse_categorical_accuracy: 0.6630
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5403 - sparse_categorical_accuracy: 0.8133
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0592 - sparse_categorical_accuracy: 0.6696
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7977 - sparse_categorical_accuracy: 0.7242
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0769 - sparse_categorical_accuracy: 0.6433
# 675/675 [==============================] - 2s 3ms/step - loss: 0.9990 - sparse_categorical_accuracy: 0.6439
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2440 - sparse_categorical_accuracy: 0.5730
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0403 - sparse_categorical_accuracy: 0.6296
# 85/85 [==============================] - 0s 3ms/step - loss: 1.2928 - sparse_categorical_accuracy: 0.5559
# 675/675 [==============================] - 2s 3ms/step - loss: 1.0845 - sparse_categorical_accuracy: 0.6369
# 85/85 [==============================] - 0s 2ms/step - loss: 1.2779 - sparse_categorical_accuracy: 0.5652
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7510 - sparse_categorical_accuracy: 0.7293
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0449 - sparse_categorical_accuracy: 0.6604
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8219 - sparse_categorical_accuracy: 0.7056
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0798 - sparse_categorical_accuracy: 0.6393
# 675/675 [==============================] - 2s 3ms/step - loss: 0.8155 - sparse_categorical_accuracy: 0.7190
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0924 - sparse_categorical_accuracy: 0.6430
# 675/675 [==============================] - 2s 3ms/step - loss: 0.5434 - sparse_categorical_accuracy: 0.8077
# 85/85 [==============================] - 0s 2ms/step - loss: 1.0898 - sparse_categorical_accuracy: 0.6626
# 675/675 [==============================] - 2s 3ms/step - loss: 0.6390 - sparse_categorical_accuracy: 0.7713
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0556 - sparse_categorical_accuracy: 0.6607
# 675/675 [==============================] - 2s 3ms/step - loss: 0.7176 - sparse_categorical_accuracy: 0.7589
# 85/85 [==============================] - 0s 3ms/step - loss: 1.0398 - sparse_categorical_accuracy: 0.6641

# %% [markdown]
# 25. Load the file ```results.csv``` using Pandas and find out which hyperparameter configuration worked best. Train a model ```my_best_model``` using these hyperparameters and evaluate it on ```test_ds```. Apply LRP to at least ten images from ```test_ds``` and visualize the results.

# %%
data = pd.read_csv("results.csv")
best_param = data.loc[data["val_acc"].idxmax()]

# %%
epochs = 100 
my_model = tf.keras.Sequential()
my_model.add(tf.keras.layers.InputLayer(input_shape=info.features["image"].shape))
my_model.add(tf.keras.layers.Flatten())


for _ in range(int(best_param['depth'])):
    my_model.add(keras.layers.Dense(activation=tf.keras.layers.ReLU(),
                                      kernel_regularizer=keras.regularizers.l2(best_param['l2_weight']),
                                   units=best_param['width']))
my_model.add(tf.keras.layers.Dense(info.features['label'].num_classes, activation=tf.keras.activations.softmax))


# your code
my_model.summary()

best_learning_rate_fn = tf.keras.optimizers.schedules.PolynomialDecay(best_param['start_learning_rate'],
                                                               epochs * sum(train_occurences) // batch_size,
                                                               1e-8,
                                                               power=0.5)

my_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=best_learning_rate_fn),
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 12288)             0
#
#  dense_8 (Dense)             (None, 512)               6291968
#
#  dense_9 (Dense)             (None, 512)               262656
#
#  dense_10 (Dense)            (None, 512)               262656
#
#  dense_11 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 6,822,410
# Trainable params: 6,822,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# your code here 
best_history = my_model.fit(
    train_ds,
    epochs=epochs,
    steps_per_epoch=np.ceil(sum(train_occurences) / batch_size),
    validation_data = val_ds
)
# Out:
# Epoch 1/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.7551 - sparse_categorical_accuracy: 0.3413 - val_loss: 1.5786 - val_sparse_categorical_accuracy: 0.3944
# Epoch 2/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.5482 - sparse_categorical_accuracy: 0.4284 - val_loss: 1.5004 - val_sparse_categorical_accuracy: 0.4637
# Epoch 3/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.4717 - sparse_categorical_accuracy: 0.4660 - val_loss: 1.4314 - val_sparse_categorical_accuracy: 0.4800
# Epoch 4/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.4094 - sparse_categorical_accuracy: 0.4889 - val_loss: 1.3963 - val_sparse_categorical_accuracy: 0.4800
# Epoch 5/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.3662 - sparse_categorical_accuracy: 0.5126 - val_loss: 1.3466 - val_sparse_categorical_accuracy: 0.5207
# Epoch 6/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.3095 - sparse_categorical_accuracy: 0.5343 - val_loss: 1.3310 - val_sparse_categorical_accuracy: 0.5322
# Epoch 7/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.2792 - sparse_categorical_accuracy: 0.5472 - val_loss: 1.2859 - val_sparse_categorical_accuracy: 0.5515
# Epoch 8/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.2475 - sparse_categorical_accuracy: 0.5568 - val_loss: 1.3160 - val_sparse_categorical_accuracy: 0.5170
# Epoch 9/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.2170 - sparse_categorical_accuracy: 0.5655 - val_loss: 1.2607 - val_sparse_categorical_accuracy: 0.5585
# Epoch 10/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.1926 - sparse_categorical_accuracy: 0.5753 - val_loss: 1.2466 - val_sparse_categorical_accuracy: 0.5619
# Epoch 11/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.1765 - sparse_categorical_accuracy: 0.5797 - val_loss: 1.2637 - val_sparse_categorical_accuracy: 0.5559
# Epoch 12/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.1488 - sparse_categorical_accuracy: 0.5872 - val_loss: 1.2272 - val_sparse_categorical_accuracy: 0.5474
# Epoch 13/100
# 675/675 [==============================] - 4s 7ms/step - loss: 1.1292 - sparse_categorical_accuracy: 0.5955 - val_loss: 1.1875 - val_sparse_categorical_accuracy: 0.5726
# Epoch 14/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.1088 - sparse_categorical_accuracy: 0.6025 - val_loss: 1.1609 - val_sparse_categorical_accuracy: 0.5774
# Epoch 15/100
# 675/675 [==============================] - 4s 6ms/step - loss: 1.0976 - sparse_categorical_accuracy: 0.6049 - val_loss: 1.1862 - val_sparse_categorical_accuracy: 0.5752
# Epoch 16/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.0669 - sparse_categorical_accuracy: 0.6215 - val_loss: 1.1210 - val_sparse_categorical_accuracy: 0.5907
# Epoch 17/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.0627 - sparse_categorical_accuracy: 0.6192 - val_loss: 1.2254 - val_sparse_categorical_accuracy: 0.5785
# Epoch 18/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.0373 - sparse_categorical_accuracy: 0.6271 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.5919
# Epoch 19/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.0244 - sparse_categorical_accuracy: 0.6337 - val_loss: 1.1007 - val_sparse_categorical_accuracy: 0.6167
# Epoch 20/100
# 675/675 [==============================] - 4s 5ms/step - loss: 1.0050 - sparse_categorical_accuracy: 0.6395 - val_loss: 1.1988 - val_sparse_categorical_accuracy: 0.5644
# Epoch 21/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9950 - sparse_categorical_accuracy: 0.6443 - val_loss: 1.1044 - val_sparse_categorical_accuracy: 0.6004
# Epoch 22/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9792 - sparse_categorical_accuracy: 0.6473 - val_loss: 1.1014 - val_sparse_categorical_accuracy: 0.5952
# Epoch 23/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9738 - sparse_categorical_accuracy: 0.6519 - val_loss: 1.0567 - val_sparse_categorical_accuracy: 0.6211
# Epoch 24/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9557 - sparse_categorical_accuracy: 0.6574 - val_loss: 1.0543 - val_sparse_categorical_accuracy: 0.6211
# Epoch 25/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9347 - sparse_categorical_accuracy: 0.6646 - val_loss: 1.0528 - val_sparse_categorical_accuracy: 0.6289
# Epoch 26/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.9179 - sparse_categorical_accuracy: 0.6727 - val_loss: 1.0450 - val_sparse_categorical_accuracy: 0.6144
# Epoch 27/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9089 - sparse_categorical_accuracy: 0.6760 - val_loss: 1.0192 - val_sparse_categorical_accuracy: 0.6389
# Epoch 28/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.9003 - sparse_categorical_accuracy: 0.6781 - val_loss: 1.0342 - val_sparse_categorical_accuracy: 0.6333
# Epoch 29/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.8889 - sparse_categorical_accuracy: 0.6824 - val_loss: 1.0265 - val_sparse_categorical_accuracy: 0.6385
# Epoch 30/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.8749 - sparse_categorical_accuracy: 0.6831 - val_loss: 1.0041 - val_sparse_categorical_accuracy: 0.6396
# Epoch 31/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.8601 - sparse_categorical_accuracy: 0.6919 - val_loss: 1.0010 - val_sparse_categorical_accuracy: 0.6489
# Epoch 32/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.8475 - sparse_categorical_accuracy: 0.6965 - val_loss: 0.9935 - val_sparse_categorical_accuracy: 0.6415
# Epoch 33/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.8357 - sparse_categorical_accuracy: 0.7037 - val_loss: 1.0131 - val_sparse_categorical_accuracy: 0.6470
# Epoch 34/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.8196 - sparse_categorical_accuracy: 0.7047 - val_loss: 1.0129 - val_sparse_categorical_accuracy: 0.6400
# Epoch 35/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.8126 - sparse_categorical_accuracy: 0.7093 - val_loss: 1.0124 - val_sparse_categorical_accuracy: 0.6319
# Epoch 36/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.8087 - sparse_categorical_accuracy: 0.7148 - val_loss: 1.0363 - val_sparse_categorical_accuracy: 0.6256
# Epoch 37/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.7844 - sparse_categorical_accuracy: 0.7226 - val_loss: 0.9842 - val_sparse_categorical_accuracy: 0.6644
# Epoch 38/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7759 - sparse_categorical_accuracy: 0.7232 - val_loss: 1.0125 - val_sparse_categorical_accuracy: 0.6467
# Epoch 39/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7681 - sparse_categorical_accuracy: 0.7261 - val_loss: 1.0238 - val_sparse_categorical_accuracy: 0.6496
# Epoch 40/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.7583 - sparse_categorical_accuracy: 0.7306 - val_loss: 0.9663 - val_sparse_categorical_accuracy: 0.6596
# Epoch 41/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7452 - sparse_categorical_accuracy: 0.7387 - val_loss: 1.0253 - val_sparse_categorical_accuracy: 0.6444
# Epoch 42/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7425 - sparse_categorical_accuracy: 0.7381 - val_loss: 1.0596 - val_sparse_categorical_accuracy: 0.6448
# Epoch 43/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7355 - sparse_categorical_accuracy: 0.7398 - val_loss: 1.0302 - val_sparse_categorical_accuracy: 0.6467
# Epoch 44/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7238 - sparse_categorical_accuracy: 0.7425 - val_loss: 1.0059 - val_sparse_categorical_accuracy: 0.6537
# Epoch 45/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.7115 - sparse_categorical_accuracy: 0.7477 - val_loss: 0.9872 - val_sparse_categorical_accuracy: 0.6659
# Epoch 46/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.7027 - sparse_categorical_accuracy: 0.7536 - val_loss: 1.0061 - val_sparse_categorical_accuracy: 0.6611
# Epoch 47/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.6890 - sparse_categorical_accuracy: 0.7586 - val_loss: 1.0046 - val_sparse_categorical_accuracy: 0.6626
# Epoch 48/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.6936 - sparse_categorical_accuracy: 0.7568 - val_loss: 0.9921 - val_sparse_categorical_accuracy: 0.6667
# Epoch 49/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.6775 - sparse_categorical_accuracy: 0.7601 - val_loss: 0.9971 - val_sparse_categorical_accuracy: 0.6570
# Epoch 50/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.6573 - sparse_categorical_accuracy: 0.7683 - val_loss: 1.0128 - val_sparse_categorical_accuracy: 0.6626
# Epoch 51/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.6586 - sparse_categorical_accuracy: 0.7675 - val_loss: 1.0140 - val_sparse_categorical_accuracy: 0.6585
# Epoch 52/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.6461 - sparse_categorical_accuracy: 0.7739 - val_loss: 0.9895 - val_sparse_categorical_accuracy: 0.6663
# Epoch 53/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.6408 - sparse_categorical_accuracy: 0.7748 - val_loss: 1.0302 - val_sparse_categorical_accuracy: 0.6559
# Epoch 54/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.6281 - sparse_categorical_accuracy: 0.7818 - val_loss: 1.0232 - val_sparse_categorical_accuracy: 0.6678
# Epoch 55/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.6202 - sparse_categorical_accuracy: 0.7844 - val_loss: 1.0563 - val_sparse_categorical_accuracy: 0.6519
# Epoch 56/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.6134 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.9830 - val_sparse_categorical_accuracy: 0.6759
# Epoch 57/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5987 - sparse_categorical_accuracy: 0.7913 - val_loss: 1.0073 - val_sparse_categorical_accuracy: 0.6711
# Epoch 58/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.6085 - sparse_categorical_accuracy: 0.7845 - val_loss: 1.0194 - val_sparse_categorical_accuracy: 0.6700
# Epoch 59/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5867 - sparse_categorical_accuracy: 0.7957 - val_loss: 0.9972 - val_sparse_categorical_accuracy: 0.6778
# Epoch 60/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.5797 - sparse_categorical_accuracy: 0.8001 - val_loss: 1.0077 - val_sparse_categorical_accuracy: 0.6770
# Epoch 61/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.5701 - sparse_categorical_accuracy: 0.8019 - val_loss: 1.0094 - val_sparse_categorical_accuracy: 0.6656
# Epoch 62/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5676 - sparse_categorical_accuracy: 0.8049 - val_loss: 1.0732 - val_sparse_categorical_accuracy: 0.6448
# Epoch 63/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.5574 - sparse_categorical_accuracy: 0.8075 - val_loss: 1.0121 - val_sparse_categorical_accuracy: 0.6819
# Epoch 64/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.8144 - val_loss: 1.0052 - val_sparse_categorical_accuracy: 0.6800
# Epoch 65/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5382 - sparse_categorical_accuracy: 0.8165 - val_loss: 1.0841 - val_sparse_categorical_accuracy: 0.6615
# Epoch 66/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.5435 - sparse_categorical_accuracy: 0.8133 - val_loss: 1.0267 - val_sparse_categorical_accuracy: 0.6667
# Epoch 67/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.5241 - sparse_categorical_accuracy: 0.8214 - val_loss: 1.0389 - val_sparse_categorical_accuracy: 0.6726
# Epoch 68/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5214 - sparse_categorical_accuracy: 0.8213 - val_loss: 1.0298 - val_sparse_categorical_accuracy: 0.6759
# Epoch 69/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.5146 - sparse_categorical_accuracy: 0.8248 - val_loss: 1.0085 - val_sparse_categorical_accuracy: 0.6830
# Epoch 70/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.5042 - sparse_categorical_accuracy: 0.8300 - val_loss: 1.0307 - val_sparse_categorical_accuracy: 0.6759
# Epoch 71/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4924 - sparse_categorical_accuracy: 0.8356 - val_loss: 1.0162 - val_sparse_categorical_accuracy: 0.6815
# Epoch 72/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4923 - sparse_categorical_accuracy: 0.8329 - val_loss: 1.1027 - val_sparse_categorical_accuracy: 0.6678
# Epoch 73/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4819 - sparse_categorical_accuracy: 0.8363 - val_loss: 1.0993 - val_sparse_categorical_accuracy: 0.6678
# Epoch 74/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4775 - sparse_categorical_accuracy: 0.8383 - val_loss: 1.0738 - val_sparse_categorical_accuracy: 0.6811
# Epoch 75/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4606 - sparse_categorical_accuracy: 0.8464 - val_loss: 1.0801 - val_sparse_categorical_accuracy: 0.6667
# Epoch 76/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4650 - sparse_categorical_accuracy: 0.8436 - val_loss: 1.0494 - val_sparse_categorical_accuracy: 0.6763
# Epoch 77/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4591 - sparse_categorical_accuracy: 0.8462 - val_loss: 1.0807 - val_sparse_categorical_accuracy: 0.6737
# Epoch 78/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4472 - sparse_categorical_accuracy: 0.8500 - val_loss: 1.0594 - val_sparse_categorical_accuracy: 0.6844
# Epoch 79/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4477 - sparse_categorical_accuracy: 0.8496 - val_loss: 1.0762 - val_sparse_categorical_accuracy: 0.6793
# Epoch 80/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8546 - val_loss: 1.1001 - val_sparse_categorical_accuracy: 0.6600
# Epoch 81/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4252 - sparse_categorical_accuracy: 0.8609 - val_loss: 1.0575 - val_sparse_categorical_accuracy: 0.6837
# Epoch 82/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4282 - sparse_categorical_accuracy: 0.8587 - val_loss: 1.0597 - val_sparse_categorical_accuracy: 0.6841
# Epoch 83/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4211 - sparse_categorical_accuracy: 0.8626 - val_loss: 1.0586 - val_sparse_categorical_accuracy: 0.6844
# Epoch 84/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.4092 - sparse_categorical_accuracy: 0.8636 - val_loss: 1.0881 - val_sparse_categorical_accuracy: 0.6781
# Epoch 85/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4099 - sparse_categorical_accuracy: 0.8664 - val_loss: 1.0844 - val_sparse_categorical_accuracy: 0.6841
# Epoch 86/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.4000 - sparse_categorical_accuracy: 0.8700 - val_loss: 1.0548 - val_sparse_categorical_accuracy: 0.6848
# Epoch 87/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.3927 - sparse_categorical_accuracy: 0.8729 - val_loss: 1.1349 - val_sparse_categorical_accuracy: 0.6641
# Epoch 88/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.3880 - sparse_categorical_accuracy: 0.8766 - val_loss: 1.0786 - val_sparse_categorical_accuracy: 0.6774
# Epoch 89/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.3793 - sparse_categorical_accuracy: 0.8772 - val_loss: 1.0792 - val_sparse_categorical_accuracy: 0.6807
# Epoch 90/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.3784 - sparse_categorical_accuracy: 0.8814 - val_loss: 1.1463 - val_sparse_categorical_accuracy: 0.6748
# Epoch 91/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.3760 - sparse_categorical_accuracy: 0.8814 - val_loss: 1.1309 - val_sparse_categorical_accuracy: 0.6781
# Epoch 92/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.3681 - sparse_categorical_accuracy: 0.8851 - val_loss: 1.1039 - val_sparse_categorical_accuracy: 0.6867
# Epoch 93/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.3593 - sparse_categorical_accuracy: 0.8865 - val_loss: 1.1129 - val_sparse_categorical_accuracy: 0.6778
# Epoch 94/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.3548 - sparse_categorical_accuracy: 0.8898 - val_loss: 1.1583 - val_sparse_categorical_accuracy: 0.6737
# Epoch 95/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.3503 - sparse_categorical_accuracy: 0.8913 - val_loss: 1.1025 - val_sparse_categorical_accuracy: 0.6889
# Epoch 96/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.3427 - sparse_categorical_accuracy: 0.8953 - val_loss: 1.0960 - val_sparse_categorical_accuracy: 0.6807
# Epoch 97/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.3387 - sparse_categorical_accuracy: 0.8984 - val_loss: 1.1018 - val_sparse_categorical_accuracy: 0.6867
# Epoch 98/100
# 675/675 [==============================] - 3s 5ms/step - loss: 0.3348 - sparse_categorical_accuracy: 0.8998 - val_loss: 1.0945 - val_sparse_categorical_accuracy: 0.6863
# Epoch 99/100
# 675/675 [==============================] - 4s 5ms/step - loss: 0.3312 - sparse_categorical_accuracy: 0.9012 - val_loss: 1.1170 - val_sparse_categorical_accuracy: 0.6856
# Epoch 100/100
# 675/675 [==============================] - 4s 6ms/step - loss: 0.3326 - sparse_categorical_accuracy: 0.8993 - val_loss: 1.1047 - val_sparse_categorical_accuracy: 0.6881

# %%
my_model.save("my_best_model.h5")

# %%
# best_model = tf.keras.models.load_model("my_best_model.h5")

# %%
test_eval = my_model.evaluate(test_ds, batch_size=batch_size)
test_eval
val_eval = my_model.evaluate(val_ds, batch_size=batch_size)
val_eval
# Out:
# 2700/2700 [==============================] - 6s 2ms/step - loss: 1.1187 - sparse_categorical_accuracy: 0.6881
# 85/85 [==============================] - 0s 4ms/step - loss: 1.1047 - sparse_categorical_accuracy: 0.6881
# [1.104670524597168, 0.6881481409072876]

# %%
# you can uncomment the following three lines to try demo_image / demo_label other than the above-defined
for item in test_ds.take(10):
    demo_test_image = item[0][:1, ...]
    demo_test_label = item[1][0]
    #     print(demo_test_image)
    #     print(demo_test_label)

    scores, _ = lrp(2, 1, my_model, demo_test_image)  # your code
    scores_input = scores[0].numpy().reshape(64, 64, 3)

    print("Predicted Probability for Predicted Class (Relevance in Output Layer):\n")
    print(f"{tf.squeeze(scores[-1]).numpy():.5f}\n")

    print("\nSum of all Relevances in Input Layer:\n")
    print(f"{tf.squeeze(tf.reduce_sum(scores[0])).numpy():.5f}\n")

    print("\nTrue Class\n")
    print(f'{demo_test_label} ({info.features["label"].names[demo_test_label]})\n')

    prediction = my_model.predict(demo_test_image)
    predicted_label = np.argmax(prediction)
    print("\nPredicted Class\n")
    print(
        f'{predicted_label} ({info.features["label"].names[predicted_label]}) with probability {prediction[0][predicted_label]}\n'
    )

    plt.subplots(1, 2, figsize=(12, 6.75))
    plt.subplot(1, 2, 1)
    plt.imshow(demo_test_image[0, ...], norm=mcolors.TwoSlopeNorm(vcenter=0.5))
    plt.xticks([])
    plt.yticks([])
    plt.subplot(1, 2, 2)
    tmp = np.sum(scores_input, axis=2)
    min_score = tmp.min()
    max_score = tmp.max()
    tmp = (tmp - min_score) / (max_score - min_score)
    plt.imshow(
        tmp,
        cmap=plt.cm.seismic,
        norm=mcolors.TwoSlopeNorm(vcenter=-min_score / (max_score - min_score)),
        alpha=1.0,
    )
    plt.xticks([])
    plt.yticks([])
    plt.show()
# Out:
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.93503
#
#
# Sum of all Relevances in Input Layer:
#
# 471229461963498083438422917120.00000
#
#
# True Class
#
# 0 (AnnualCrop)
#
# 1/1 [==============================] - 0s 60ms/step
#
# Predicted Class
#
# 0 (AnnualCrop) with probability 0.9350306391716003
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.54152
#
#
# Sum of all Relevances in Input Layer:
#
# 31559095884819827694141177856.00000
#
#
# True Class
#
# 3 (Highway)
#
# 1/1 [==============================] - 0s 17ms/step
#
# Predicted Class
#
# 3 (Highway) with probability 0.5415244698524475
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.95971
#
#
# Sum of all Relevances in Input Layer:
#
# 27727492863331193613346406400.00000
#
#
# True Class
#
# 7 (Residential)
#
# 1/1 [==============================] - 0s 19ms/step
#
# Predicted Class
#
# 7 (Residential) with probability 0.9597139358520508
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.68968
#
#
# Sum of all Relevances in Input Layer:
#
# 91981054872248300582486409216.00000
#
#
# True Class
#
# 9 (SeaLake)
#
# 1/1 [==============================] - 0s 26ms/step
#
# Predicted Class
#
# 9 (SeaLake) with probability 0.6896756291389465
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.57579
#
#
# Sum of all Relevances in Input Layer:
#
# 53194993354222495377483890688.00000
#
#
# True Class
#
# 3 (Highway)
#
# 1/1 [==============================] - 0s 18ms/step
#
# Predicted Class
#
# 4 (Industrial) with probability 0.5757941007614136
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.61080
#
#
# Sum of all Relevances in Input Layer:
#
# 26439599631390018231376805888.00000
#
#
# True Class
#
# 9 (SeaLake)
#
# 1/1 [==============================] - 0s 19ms/step
#
# Predicted Class
#
# 9 (SeaLake) with probability 0.6107956171035767
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.64144
#
#
# Sum of all Relevances in Input Layer:
#
# 32961312886944794317089144832.00000
#
#
# True Class
#
# 9 (SeaLake)
#
# 1/1 [==============================] - 0s 21ms/step
#
# Predicted Class
#
# 9 (SeaLake) with probability 0.6414380073547363
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.67598
#
#
# Sum of all Relevances in Input Layer:
#
# 22905531671337827582093557760.00000
#
#
# True Class
#
# 6 (PermanentCrop)
#
# 1/1 [==============================] - 0s 21ms/step
#
# Predicted Class
#
# 5 (Pasture) with probability 0.6759752631187439
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.84716
#
#
# Sum of all Relevances in Input Layer:
#
# 67527158400873656597371420672.00000
#
#
# True Class
#
# 5 (Pasture)
#
# 1/1 [==============================] - 0s 17ms/step
#
# Predicted Class
#
# 5 (Pasture) with probability 0.847156822681427
# Predicted Probability for Predicted Class (Relevance in Output Layer):
#
# 0.65701
#
#
# Sum of all Relevances in Input Layer:
#
# 21120736870969659521803223040.00000
#
#
# True Class
#
# 3 (Highway)
#
# 1/1 [==============================] - 0s 19ms/step
#
# Predicted Class
#
# 3 (Highway) with probability 0.6570108532905579

# %% [markdown]
# ### Confusion matrix
#
# The confusion matrix is a useful tool to evaluate your model's performance on each specific class rather than looking at an overall accuracy as above.
#
# 26. Make yourself familiar with the concept of the confusion matrix, complete and execute the code below using your ```my_best_model```. Discuss the results with your teammate. The information under https://www.tensorflow.org/api_docs/python/tf/math/confusion_matrix could be helpful.

# %%
def show_confusion_matrix(cm, labels):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, xticklabels=labels, yticklabels=labels, annot=True, fmt="g")
    plt.xlabel("Prediction")
    plt.ylabel("Label")
    plt.show()

# %%
true_test_labels = np.array([item[1][0] for item in test_ds])  # your code
predicted_test_labels = np.array(
    [my_model.predict(item[0][:1, ...]).argmax(axis=-1) for item in test_ds]
)  # your code
num_classes = info.features["label"].num_classes  # your code
confusion_mtx = tf.math.confusion_matrix(
    true_test_labels, predicted_test_labels, num_classes
)
show_confusion_matrix(confusion_mtx, info.features["label"].names)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# ...
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Submission due on November 20th
#
# 27. Submit your completed notebook, your ```my_best_model.h5```, the files you used to carry out hyperparameter tuning on the cluster, and your ```results.csv``` via your group's folder in Stud.IP **not later than November 20th 2022**.

# %%
import tensorflow as tf

print(tf.__version__)
print(len(tf.config.list_physical_devices("GPU")) > 0)
# Out:
# 2.10.1
# True
